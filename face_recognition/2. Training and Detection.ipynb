# %% [markdown]
# # 0. Setup Paths

# %%
import os

# %%
CUSTOM_MODEL_NAME = 'my_ssd_mobnet' 
PRETRAINED_MODEL_NAME = 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8'
PRETRAINED_MODEL_URL = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz'
TF_RECORD_SCRIPT_NAME = 'generate_tfrecord.py'
LABEL_MAP_NAME = 'label_map.pbtxt'

# %%
paths = {
    'WORKSPACE_PATH': os.path.join('Tensorflow', 'workspace'),
    'SCRIPTS_PATH': os.path.join('Tensorflow','scripts'),
    'APIMODEL_PATH': os.path.join('Tensorflow','models'),
    'ANNOTATION_PATH': os.path.join('Tensorflow', 'workspace','annotations'),
    'IMAGE_PATH': os.path.join('Tensorflow', 'workspace','images'),
    'MODEL_PATH': os.path.join('Tensorflow', 'workspace','models'),
    'PRETRAINED_MODEL_PATH': os.path.join('Tensorflow', 'workspace','pre-trained-models'),
    'CHECKPOINT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME), 
    'OUTPUT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'export'), 
    'TFJS_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfjsexport'), 
    'TFLITE_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfliteexport'), 
    'PROTOC_PATH':os.path.join('Tensorflow','protoc')
 }

# %%
files = {
    'PIPELINE_CONFIG':os.path.join('Tensorflow', 'workspace','models', CUSTOM_MODEL_NAME, 'pipeline.config'),
    'TF_RECORD_SCRIPT': os.path.join(paths['SCRIPTS_PATH'], TF_RECORD_SCRIPT_NAME), 
    'LABELMAP': os.path.join(paths['ANNOTATION_PATH'], LABEL_MAP_NAME)
}

# %%
for path in paths.values():
    if not os.path.exists(path):
        if os.name == 'posix':
            # !mkdir -p {path}
        if os.name == 'nt':
            # !mkdir {path}

# %% [markdown]
# # 1. Download TF Models Pretrained Models from Tensorflow Model Zoo and Install TFOD

# %%
# https://www.tensorflow.org/install/source_windows

# %%
if os.name=='nt':
    # !pip install wget
    import wget
# Out:
# Requirement already satisfied: wget in c:\users\noa_on_air\new_tensor\tfodcourse\tfod\lib\site-packages (3.2)

# %%
if not os.path.exists(os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection')):
    # !git clone https://github.com/tensorflow/models {paths['APIMODEL_PATH']}

# %%
# Install Tensorflow Object Detection 
if os.name=='posix':  
    # !apt-get install protobuf-compiler
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && cp object_detection/packages/tf2/setup.py . && python -m pip install . 
    
if os.name=='nt':
    url="https://github.com/protocolbuffers/protobuf/releases/download/v3.15.6/protoc-3.15.6-win64.zip"
    wget.download(url)
    # !move protoc-3.15.6-win64.zip {paths['PROTOC_PATH']}
    # !cd {paths['PROTOC_PATH']} && tar -xf protoc-3.15.6-win64.zip
    os.environ['PATH'] += os.pathsep + os.path.abspath(os.path.join(paths['PROTOC_PATH'], 'bin'))   
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && copy object_detection\\packages\\tf2\\setup.py setup.py && python setup.py build && python setup.py install
    # !cd Tensorflow/models/research/slim && pip install -e .

# %%
VERIFICATION_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'builders', 'model_builder_tf2_test.py')
# Verify Installation
# !python {VERIFICATION_SCRIPT}
# Out:
# Running tests under Python 3.8.8: C:\Users\noa_on_air\new_tensor\TFODCourse\tfod\Scripts\python.exe
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# 2021-10-12 18:46:43.994063: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-10-12 18:46:45.111932: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2149 MB memory:  -> device: 0, name: GeForce GTX 1650 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# C:\Users\noa_on_air\new_tensor\TFODCourse\tfod\lib\site-packages\object_detection-0.1-py3.8.egg\object_detection\builders\model_builder.py:1091: DeprecationWarning: The 'warn' function is deprecated, use 'warning' instead
#   logging.warn(('Building experimental DeepMAC meta-arch.'
# W1012 18:46:45.421751 26332 model_builder.py:1091] Building experimental DeepMAC meta-arch. Some features may be omitted.
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 1.7s
# I1012 18:46:45.676513 26332 test_util.py:2188] time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 1.7s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_deepmac
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.8s
# I1012 18:46:46.482441 26332 test_util.py:2188] time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.8s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.2s
# I1012 18:46:46.681990 26332 test_util.py:2188] time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.2s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.19s
# I1012 18:46:46.871572 26332 test_util.py:2188] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.19s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 1.44s
# I1012 18:46:48.310368 26332 test_util.py:2188] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 1.44s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# [ RUN      ] ModelBuilderTF2Test.test_create_experimental_model
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# I1012 18:46:48.321394 26332 test_util.py:2188] time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# [       OK ] ModelBuilderTF2Test.test_create_experimental_model
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.02s
# I1012 18:46:48.347327 26332 test_util.py:2188] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.02s
# I1012 18:46:48.364824 26332 test_util.py:2188] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.01s
# I1012 18:46:48.378413 26332 test_util.py:2188] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.01s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.09s
# I1012 18:46:48.463802 26332 test_util.py:2188] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.09s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.08s
# I1012 18:46:48.547548 26332 test_util.py:2188] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.08s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.09s
# I1012 18:46:48.634346 26332 test_util.py:2188] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.09s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.08s
# I1012 18:46:48.718091 26332 test_util.py:2188] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.08s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.08s
# I1012 18:46:48.796912 26332 test_util.py:2188] time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.08s
# [       OK ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.02s
# I1012 18:46:48.818854 26332 test_util.py:2188] time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# I1012 18:46:49.055239 26332 ssd_efficientnet_bifpn_feature_extractor.py:142] EfficientDet EfficientNet backbone version: efficientnet-b0
# I1012 18:46:49.055239 26332 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 64
# I1012 18:46:49.055239 26332 ssd_efficientnet_bifpn_feature_extractor.py:145] EfficientDet BiFPN num iterations: 3
# I1012 18:46:49.057215 26332 efficientnet_model.py:147] round_filter input=32 output=32
# I1012 18:46:49.067188 26332 efficientnet_model.py:147] round_filter input=32 output=32
# I1012 18:46:49.067188 26332 efficientnet_model.py:147] round_filter input=16 output=16
# I1012 18:46:49.117057 26332 efficientnet_model.py:147] round_filter input=16 output=16
# I1012 18:46:49.117057 26332 efficientnet_model.py:147] round_filter input=24 output=24
# I1012 18:46:49.219813 26332 efficientnet_model.py:147] round_filter input=24 output=24
# I1012 18:46:49.219813 26332 efficientnet_model.py:147] round_filter input=40 output=40
# I1012 18:46:49.317552 26332 efficientnet_model.py:147] round_filter input=40 output=40
# I1012 18:46:49.318632 26332 efficientnet_model.py:147] round_filter input=80 output=80
# I1012 18:46:49.458784 26332 efficientnet_model.py:147] round_filter input=80 output=80
# I1012 18:46:49.458784 26332 efficientnet_model.py:147] round_filter input=112 output=112
# I1012 18:46:49.619876 26332 efficientnet_model.py:147] round_filter input=112 output=112
# I1012 18:46:49.619876 26332 efficientnet_model.py:147] round_filter input=192 output=192
# I1012 18:46:49.816262 26332 efficientnet_model.py:147] round_filter input=192 output=192
# I1012 18:46:49.816262 26332 efficientnet_model.py:147] round_filter input=320 output=320
# I1012 18:46:49.862105 26332 efficientnet_model.py:147] round_filter input=1280 output=1280
# I1012 18:46:49.880057 26332 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.0, resolution=224, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1012 18:46:49.917955 26332 ssd_efficientnet_bifpn_feature_extractor.py:142] EfficientDet EfficientNet backbone version: efficientnet-b1
# I1012 18:46:49.917955 26332 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 88
# I1012 18:46:49.918952 26332 ssd_efficientnet_bifpn_feature_extractor.py:145] EfficientDet BiFPN num iterations: 4
# I1012 18:46:49.919950 26332 efficientnet_model.py:147] round_filter input=32 output=32
# I1012 18:46:49.929923 26332 efficientnet_model.py:147] round_filter input=32 output=32
# I1012 18:46:49.929923 26332 efficientnet_model.py:147] round_filter input=16 output=16
# I1012 18:46:50.028659 26332 efficientnet_model.py:147] round_filter input=16 output=16
# I1012 18:46:50.028659 26332 efficientnet_model.py:147] round_filter input=24 output=24
# I1012 18:46:50.214165 26332 efficientnet_model.py:147] round_filter input=24 output=24
# I1012 18:46:50.214165 26332 efficientnet_model.py:147] round_filter input=40 output=40
# I1012 18:46:50.429151 26332 efficientnet_model.py:147] round_filter input=40 output=40
# I1012 18:46:50.429151 26332 efficientnet_model.py:147] round_filter input=80 output=80
# I1012 18:46:50.657082 26332 efficientnet_model.py:147] round_filter input=80 output=80
# I1012 18:46:50.657082 26332 efficientnet_model.py:147] round_filter input=112 output=112
# I1012 18:46:50.864315 26332 efficientnet_model.py:147] round_filter input=112 output=112
# I1012 18:46:50.864315 26332 efficientnet_model.py:147] round_filter input=192 output=192
# I1012 18:46:51.208659 26332 efficientnet_model.py:147] round_filter input=192 output=192
# I1012 18:46:51.208659 26332 efficientnet_model.py:147] round_filter input=320 output=320
# I1012 18:46:51.312467 26332 efficientnet_model.py:147] round_filter input=1280 output=1280
# I1012 18:46:51.330782 26332 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.1, resolution=240, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1012 18:46:51.382661 26332 ssd_efficientnet_bifpn_feature_extractor.py:142] EfficientDet EfficientNet backbone version: efficientnet-b2
# I1012 18:46:51.382661 26332 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 112
# I1012 18:46:51.382661 26332 ssd_efficientnet_bifpn_feature_extractor.py:145] EfficientDet BiFPN num iterations: 5
# I1012 18:46:51.384656 26332 efficientnet_model.py:147] round_filter input=32 output=32
# I1012 18:46:51.398619 26332 efficientnet_model.py:147] round_filter input=32 output=32
# I1012 18:46:51.398619 26332 efficientnet_model.py:147] round_filter input=16 output=16
# I1012 18:46:51.488947 26332 efficientnet_model.py:147] round_filter input=16 output=16
# I1012 18:46:51.488947 26332 efficientnet_model.py:147] round_filter input=24 output=24
# I1012 18:46:51.643738 26332 efficientnet_model.py:147] round_filter input=24 output=24
# I1012 18:46:51.643738 26332 efficientnet_model.py:147] round_filter input=40 output=48
# I1012 18:46:51.804805 26332 efficientnet_model.py:147] round_filter input=40 output=48
# I1012 18:46:51.805802 26332 efficientnet_model.py:147] round_filter input=80 output=88
# I1012 18:46:52.020874 26332 efficientnet_model.py:147] round_filter input=80 output=88
# I1012 18:46:52.020874 26332 efficientnet_model.py:147] round_filter input=112 output=120
# I1012 18:46:52.240784 26332 efficientnet_model.py:147] round_filter input=112 output=120
# I1012 18:46:52.240784 26332 efficientnet_model.py:147] round_filter input=192 output=208
# I1012 18:46:52.501118 26332 efficientnet_model.py:147] round_filter input=192 output=208
# I1012 18:46:52.501118 26332 efficientnet_model.py:147] round_filter input=320 output=352
# I1012 18:46:52.605713 26332 efficientnet_model.py:147] round_filter input=1280 output=1408
# I1012 18:46:52.624663 26332 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=1.1, depth_coefficient=1.2, resolution=260, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1012 18:46:52.677552 26332 ssd_efficientnet_bifpn_feature_extractor.py:142] EfficientDet EfficientNet backbone version: efficientnet-b3
# I1012 18:46:52.677552 26332 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 160
# I1012 18:46:52.677552 26332 ssd_efficientnet_bifpn_feature_extractor.py:145] EfficientDet BiFPN num iterations: 6
# I1012 18:46:52.678550 26332 efficientnet_model.py:147] round_filter input=32 output=40
# I1012 18:46:52.689524 26332 efficientnet_model.py:147] round_filter input=32 output=40
# I1012 18:46:52.690520 26332 efficientnet_model.py:147] round_filter input=16 output=24
# I1012 18:46:52.770273 26332 efficientnet_model.py:147] round_filter input=16 output=24
# I1012 18:46:52.770273 26332 efficientnet_model.py:147] round_filter input=24 output=32
# I1012 18:46:52.928882 26332 efficientnet_model.py:147] round_filter input=24 output=32
# I1012 18:46:52.928882 26332 efficientnet_model.py:147] round_filter input=40 output=48
# I1012 18:46:53.098208 26332 efficientnet_model.py:147] round_filter input=40 output=48
# I1012 18:46:53.098208 26332 efficientnet_model.py:147] round_filter input=80 output=96
# I1012 18:46:53.368427 26332 efficientnet_model.py:147] round_filter input=80 output=96
# I1012 18:46:53.368427 26332 efficientnet_model.py:147] round_filter input=112 output=136
# I1012 18:46:53.823567 26332 efficientnet_model.py:147] round_filter input=112 output=136
# I1012 18:46:53.823567 26332 efficientnet_model.py:147] round_filter input=192 output=232
# I1012 18:46:54.170674 26332 efficientnet_model.py:147] round_filter input=192 output=232
# I1012 18:46:54.170674 26332 efficientnet_model.py:147] round_filter input=320 output=384
# I1012 18:46:54.265417 26332 efficientnet_model.py:147] round_filter input=1280 output=1536
# I1012 18:46:54.283375 26332 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=1.2, depth_coefficient=1.4, resolution=300, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1012 18:46:54.330241 26332 ssd_efficientnet_bifpn_feature_extractor.py:142] EfficientDet EfficientNet backbone version: efficientnet-b4
# I1012 18:46:54.330241 26332 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 224
# I1012 18:46:54.330241 26332 ssd_efficientnet_bifpn_feature_extractor.py:145] EfficientDet BiFPN num iterations: 7
# I1012 18:46:54.331239 26332 efficientnet_model.py:147] round_filter input=32 output=48
# I1012 18:46:54.341212 26332 efficientnet_model.py:147] round_filter input=32 output=48
# I1012 18:46:54.341212 26332 efficientnet_model.py:147] round_filter input=16 output=24
# I1012 18:46:54.417012 26332 efficientnet_model.py:147] round_filter input=16 output=24
# I1012 18:46:54.417012 26332 efficientnet_model.py:147] round_filter input=24 output=32
# I1012 18:46:54.601163 26332 efficientnet_model.py:147] round_filter input=24 output=32
# I1012 18:46:54.601163 26332 efficientnet_model.py:147] round_filter input=40 output=56
# I1012 18:46:54.788291 26332 efficientnet_model.py:147] round_filter input=40 output=56
# I1012 18:46:54.788291 26332 efficientnet_model.py:147] round_filter input=80 output=112
# I1012 18:46:55.082966 26332 efficientnet_model.py:147] round_filter input=80 output=112
# I1012 18:46:55.082966 26332 efficientnet_model.py:147] round_filter input=112 output=160
# I1012 18:46:55.394961 26332 efficientnet_model.py:147] round_filter input=112 output=160
# I1012 18:46:55.394961 26332 efficientnet_model.py:147] round_filter input=192 output=272
# I1012 18:46:55.797558 26332 efficientnet_model.py:147] round_filter input=192 output=272
# I1012 18:46:55.797558 26332 efficientnet_model.py:147] round_filter input=320 output=448
# I1012 18:46:55.889312 26332 efficientnet_model.py:147] round_filter input=1280 output=1792
# I1012 18:46:55.907233 26332 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=1.4, depth_coefficient=1.8, resolution=380, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1012 18:46:55.963088 26332 ssd_efficientnet_bifpn_feature_extractor.py:142] EfficientDet EfficientNet backbone version: efficientnet-b5
# I1012 18:46:55.963088 26332 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 288
# I1012 18:46:55.963088 26332 ssd_efficientnet_bifpn_feature_extractor.py:145] EfficientDet BiFPN num iterations: 7
# I1012 18:46:55.964094 26332 efficientnet_model.py:147] round_filter input=32 output=48
# I1012 18:46:55.974059 26332 efficientnet_model.py:147] round_filter input=32 output=48
# I1012 18:46:55.974059 26332 efficientnet_model.py:147] round_filter input=16 output=24
# I1012 18:46:56.226383 26332 efficientnet_model.py:147] round_filter input=16 output=24
# I1012 18:46:56.226383 26332 efficientnet_model.py:147] round_filter input=24 output=40
# I1012 18:46:56.484725 26332 efficientnet_model.py:147] round_filter input=24 output=40
# I1012 18:46:56.484725 26332 efficientnet_model.py:147] round_filter input=40 output=64
# I1012 18:46:56.735058 26332 efficientnet_model.py:147] round_filter input=40 output=64
# I1012 18:46:56.736052 26332 efficientnet_model.py:147] round_filter input=80 output=128
# I1012 18:46:57.093474 26332 efficientnet_model.py:147] round_filter input=80 output=128
# I1012 18:46:57.093474 26332 efficientnet_model.py:147] round_filter input=112 output=176
# I1012 18:46:57.448564 26332 efficientnet_model.py:147] round_filter input=112 output=176
# I1012 18:46:57.448564 26332 efficientnet_model.py:147] round_filter input=192 output=304
# I1012 18:46:57.891463 26332 efficientnet_model.py:147] round_filter input=192 output=304
# I1012 18:46:57.892472 26332 efficientnet_model.py:147] round_filter input=320 output=512
# I1012 18:46:58.079449 26332 efficientnet_model.py:147] round_filter input=1280 output=2048
# I1012 18:46:58.098368 26332 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=1.6, depth_coefficient=2.2, resolution=456, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1012 18:46:58.168180 26332 ssd_efficientnet_bifpn_feature_extractor.py:142] EfficientDet EfficientNet backbone version: efficientnet-b6
# I1012 18:46:58.168180 26332 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 384
# I1012 18:46:58.168180 26332 ssd_efficientnet_bifpn_feature_extractor.py:145] EfficientDet BiFPN num iterations: 8
# I1012 18:46:58.169177 26332 efficientnet_model.py:147] round_filter input=32 output=56
# I1012 18:46:58.179151 26332 efficientnet_model.py:147] round_filter input=32 output=56
# I1012 18:46:58.179151 26332 efficientnet_model.py:147] round_filter input=16 output=32
# I1012 18:46:58.315785 26332 efficientnet_model.py:147] round_filter input=16 output=32
# I1012 18:46:58.315785 26332 efficientnet_model.py:147] round_filter input=24 output=40
# I1012 18:46:58.599060 26332 efficientnet_model.py:147] round_filter input=24 output=40
# I1012 18:46:58.599060 26332 efficientnet_model.py:147] round_filter input=40 output=72
# I1012 18:46:59.010512 26332 efficientnet_model.py:147] round_filter input=40 output=72
# I1012 18:46:59.010512 26332 efficientnet_model.py:147] round_filter input=80 output=144
# I1012 18:46:59.427405 26332 efficientnet_model.py:147] round_filter input=80 output=144
# I1012 18:46:59.427405 26332 efficientnet_model.py:147] round_filter input=112 output=200
# I1012 18:46:59.808351 26332 efficientnet_model.py:147] round_filter input=112 output=200
# I1012 18:46:59.808351 26332 efficientnet_model.py:147] round_filter input=192 output=344
# I1012 18:47:00.353898 26332 efficientnet_model.py:147] round_filter input=192 output=344
# I1012 18:47:00.353898 26332 efficientnet_model.py:147] round_filter input=320 output=576
# I1012 18:47:00.496521 26332 efficientnet_model.py:147] round_filter input=1280 output=2304
# I1012 18:47:00.514473 26332 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=1.8, depth_coefficient=2.6, resolution=528, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I1012 18:47:00.594258 26332 ssd_efficientnet_bifpn_feature_extractor.py:142] EfficientDet EfficientNet backbone version: efficientnet-b7
# I1012 18:47:00.594258 26332 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 384
# I1012 18:47:00.594258 26332 ssd_efficientnet_bifpn_feature_extractor.py:145] EfficientDet BiFPN num iterations: 8
# I1012 18:47:00.595255 26332 efficientnet_model.py:147] round_filter input=32 output=64
# I1012 18:47:00.605230 26332 efficientnet_model.py:147] round_filter input=32 output=64
# I1012 18:47:00.605230 26332 efficientnet_model.py:147] round_filter input=16 output=32
# I1012 18:47:00.760605 26332 efficientnet_model.py:147] round_filter input=16 output=32
# I1012 18:47:00.760605 26332 efficientnet_model.py:147] round_filter input=24 output=48
# I1012 18:47:01.089824 26332 efficientnet_model.py:147] round_filter input=24 output=48
# I1012 18:47:01.090819 26332 efficientnet_model.py:147] round_filter input=40 output=80
# I1012 18:47:01.588138 26332 efficientnet_model.py:147] round_filter input=40 output=80
# I1012 18:47:01.588138 26332 efficientnet_model.py:147] round_filter input=80 output=160
# I1012 18:47:02.101733 26332 efficientnet_model.py:147] round_filter input=80 output=160
# I1012 18:47:02.101733 26332 efficientnet_model.py:147] round_filter input=112 output=224
# I1012 18:47:02.619459 26332 efficientnet_model.py:147] round_filter input=112 output=224
# I1012 18:47:02.619459 26332 efficientnet_model.py:147] round_filter input=192 output=384
# I1012 18:47:03.244930 26332 efficientnet_model.py:147] round_filter input=192 output=384
# I1012 18:47:03.244930 26332 efficientnet_model.py:147] round_filter input=320 output=640
# I1012 18:47:03.462888 26332 efficientnet_model.py:147] round_filter input=1280 output=2560
# I1012 18:47:03.481316 26332 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=2.0, depth_coefficient=3.1, resolution=600, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 14.76s
# I1012 18:47:03.579024 26332 test_util.py:2188] time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 14.76s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# I1012 18:47:03.583049 26332 test_util.py:2188] time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# I1012 18:47:03.584043 26332 test_util.py:2188] time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTF2Test.test_invalid_model_config_proto
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# I1012 18:47:03.584043 26332 test_util.py:2188] time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# I1012 18:47:03.586036 26332 test_util.py:2188] time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTF2Test.test_session
# [  SKIPPED ] ModelBuilderTF2Test.test_session
# [ RUN      ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# I1012 18:47:03.587033 26332 test_util.py:2188] time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTF2Test.test_unknown_meta_architecture
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# I1012 18:47:03.587033 26332 test_util.py:2188] time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# I1012 18:47:03.587033 26332 test_util.py:2188] time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 24 tests in 19.610s
#
# OK (skipped=1)

# %%
# !pip install pyyaml

# %%
# !pip install Pillow

# %%
# !pip install tensorflow --upgrade

# %%
# !pip uninstall protobuf matplotlib -y
# !pip install protobuf matplotlib==3.2

# %%
import object_detection

# %%
# !pip list

# %%
if os.name =='posix':
    # !wget {PRETRAINED_MODEL_URL}
    # !mv {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
if os.name == 'nt':
    wget.download(PRETRAINED_MODEL_URL)
    # !move {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
# Out:
#   6% [....                                                                    ]  1327104 / 20515344
#  16% [...........                                                             ]  3293184 / 20515344
#  25% [..................                                                      ]  5218304 / 20515344
#  31% [......................                                                  ]  6422528 / 20515344
#  40% [.............................                                           ]  8339456 / 20515344
#  50% [....................................                                    ] 10395648 / 20515344
#  59% [...........................................                             ] 12296192 / 20515344
#  69% [..................................................                      ] 14327808 / 20515344
#  78% [........................................................                ] 16089088 / 20515344
#  85% [.............................................................           ] 17580032 / 20515344
#  93% [...................................................................     ] 19218432 / 20515344
# 100% [........................................................................] 20515344 / 20515344
#         1개 파일을 이동했습니다.
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/checkpoint
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.index
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/saved_model.pb
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.data-00000-of-00001
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.index

# %% [markdown]
# # 2. Create Label Map

# %%
labels = [{'name':'student', 'id':1}]

with open(files['LABELMAP'], 'w') as f:
    for label in labels:
        f.write('item { \n')
        f.write('\tname:\'{}\'\n'.format(label['name']))
        f.write('\tid:{}\n'.format(label['id']))
        f.write('}\n')

# %% [markdown]
# # 3. Create TF records

# %%
# OPTIONAL IF RUNNING ON COLAB
ARCHIVE_FILES = os.path.join(paths['IMAGE_PATH'], 'archive.tar.gz')
if os.path.exists(ARCHIVE_FILES):
  # !tar -zxvf {ARCHIVE_FILES}

# %%
if not os.path.exists(files['TF_RECORD_SCRIPT']):
    # !git clone https://github.com/nicknochnack/GenerateTFRecord {paths['SCRIPTS_PATH']}
# Out:
# Cloning into 'Tensorflow\scripts'...

# %%
# !pip install pytz
# Out:
# Collecting pytz
#   Using cached pytz-2021.3-py2.py3-none-any.whl (503 kB)
# Installing collected packages: pytz
# Successfully installed pytz-2021.3

# %%
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'train')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'train.record')} 
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'test')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'test.record')}
# Out:
# Successfully created the TFRecord file: Tensorflow\workspace\annotations\train.record
# Successfully created the TFRecord file: Tensorflow\workspace\annotations\test.record

# %% [markdown]
# # 4. Copy Model Config to Training Folder

# %%
if os.name =='posix':
    # !cp {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
if os.name == 'nt':
    # !copy {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
# Out:
#         1개 파일이 복사되었습니다.

# %% [markdown]
# # 5. Update Config For Transfer Learning

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %%
config = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])

# %%
config
# Out:
# {'model': ssd {
#    num_classes: 90
#    image_resizer {
#      fixed_shape_resizer {
#        height: 320
#        width: 320
#      }
#    }
#    feature_extractor {
#      type: "ssd_mobilenet_v2_fpn_keras"
#      depth_multiplier: 1.0
#      min_depth: 16
#      conv_hyperparams {
#        regularizer {
#          l2_regularizer {
#            weight: 3.9999998989515007e-05
#          }
#        }
#        initializer {
#          random_normal_initializer {
#            mean: 0.0
#            stddev: 0.009999999776482582
#          }
#        }
#        activation: RELU_6
#        batch_norm {
#          decay: 0.996999979019165
#          scale: true
#          epsilon: 0.0010000000474974513
#        }
#      }
#      use_depthwise: true
#      override_base_feature_extractor_hyperparams: true
#      fpn {
#        min_level: 3
#        max_level: 7
#        additional_layer_depth: 128
#      }
#    }
#    box_coder {
#      faster_rcnn_box_coder {
#        y_scale: 10.0
#        x_scale: 10.0
#        height_scale: 5.0
#        width_scale: 5.0
#      }
#    }
#    matcher {
#      argmax_matcher {
#        matched_threshold: 0.5
#        unmatched_threshold: 0.5
#        ignore_thresholds: false
#        negatives_lower_than_unmatched: true
#        force_match_for_each_row: true
#        use_matmul_gather: true
#      }
#    }
#    similarity_calculator {
#      iou_similarity {
#      }
#    }
#    box_predictor {
#      weight_shared_convolutional_box_predictor {
#        conv_hyperparams {
#          regularizer {
#            l2_regularizer {
#              weight: 3.9999998989515007e-05
#            }
#          }
#          initializer {
#            random_normal_initializer {
#              mean: 0.0
#              stddev: 0.009999999776482582
#            }
#          }
#          activation: RELU_6
#          batch_norm {
#            decay: 0.996999979019165
#            scale: true
#            epsilon: 0.0010000000474974513
#          }
#        }
#        depth: 128
#        num_layers_before_predictor: 4
#        kernel_size: 3
#        class_prediction_bias_init: -4.599999904632568
#        share_prediction_tower: true
#        use_depthwise: true
#      }
#    }
#    anchor_generator {
#      multiscale_anchor_generator {
#        min_level: 3
#        max_level: 7
#        anchor_scale: 4.0
#        aspect_ratios: 1.0
#        aspect_ratios: 2.0
#        aspect_ratios: 0.5
#        scales_per_octave: 2
#      }
#    }
#    post_processing {
#      batch_non_max_suppression {
#        score_threshold: 9.99999993922529e-09
#        iou_threshold: 0.6000000238418579
#        max_detections_per_class: 100
#        max_total_detections: 100
#        use_static_shapes: false
#      }
#      score_converter: SIGMOID
#    }
#    normalize_loss_by_num_matches: true
#    loss {
#      localization_loss {
#        weighted_smooth_l1 {
#        }
#      }
#      classification_loss {
#        weighted_sigmoid_focal {
#          gamma: 2.0
#          alpha: 0.25
#        }
#      }
#      classification_weight: 1.0
#      localization_weight: 1.0
#    }
#    encode_background_as_zeros: true
#    normalize_loc_loss_by_codesize: true
#    inplace_batchnorm_update: true
#    freeze_batchnorm: false
#  },
#  'train_config': batch_size: 128
#  data_augmentation_options {
#    random_horizontal_flip {
#    }
#  }
#  data_augmentation_options {
#    random_crop_image {
#      min_object_covered: 0.0
#      min_aspect_ratio: 0.75
#      max_aspect_ratio: 3.0
#      min_area: 0.75
#      max_area: 1.0
#      overlap_thresh: 0.0
#    }
#  }
#  sync_replicas: true
#  optimizer {
#    momentum_optimizer {
#      learning_rate {
#        cosine_decay_learning_rate {
#          learning_rate_base: 0.07999999821186066
#          total_steps: 50000
#          warmup_learning_rate: 0.026666000485420227
#          warmup_steps: 1000
#        }
#      }
#      momentum_optimizer_value: 0.8999999761581421
#    }
#    use_moving_average: false
#  }
#  fine_tune_checkpoint: "PATH_TO_BE_CONFIGURED"
#  num_steps: 50000
#  startup_delay_steps: 0.0
#  replicas_to_aggregate: 8
#  max_number_of_boxes: 100
#  unpad_groundtruth_tensors: false
#  fine_tune_checkpoint_type: "classification"
#  fine_tune_checkpoint_version: V2,
#  'train_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  },
#  'eval_config': metrics_set: "coco_detection_metrics"
#  use_moving_averages: false,
#  'eval_input_configs': [label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }
#  ],
#  'eval_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }}

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "r") as f:                                                                                                                                                                                                                     
    proto_str = f.read()                                                                                                                                                                                                                                          
    text_format.Merge(proto_str, pipeline_config)

# %%
pipeline_config.model.ssd.num_classes = len(labels)
pipeline_config.train_config.batch_size = 4
pipeline_config.train_config.fine_tune_checkpoint = os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'checkpoint', 'ckpt-0')
pipeline_config.train_config.fine_tune_checkpoint_type = "detection"
pipeline_config.train_input_reader.label_map_path= files['LABELMAP']
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'train.record')]
pipeline_config.eval_input_reader[0].label_map_path = files['LABELMAP']
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'test.record')]

# %%
config_text = text_format.MessageToString(pipeline_config)                                                                                                                                                                                                        
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "wb") as f:                                                                                                                                                                                                                     
    f.write(config_text)

# %% [markdown]
# # 6. Train the model

# %%
TRAINING_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'model_main_tf2.py')

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --num_train_steps=2000".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'])

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\model_main_tf2.py --model_dir=Tensorflow\workspace\models\my_ssd_mobnet --pipeline_config_path=Tensorflow\workspace\models\my_ssd_mobnet\pipeline.config --num_train_steps=2000

# %%
# !{command}
# Out:
# Traceback (most recent call last):
#   File "Tensorflow\models\research\object_detection\model_main_tf2.py", line 32, in <module>
#     from object_detection import model_lib_v2
#   File "C:\Users\noa_on_air\new_tensor\TFODCourse\tfod\lib\site-packages\object_detection-0.1-py3.8.egg\object_detection\model_lib_v2.py", line 29, in <module>
#     from object_detection import eval_util
#   File "C:\Users\noa_on_air\new_tensor\TFODCourse\tfod\lib\site-packages\object_detection-0.1-py3.8.egg\object_detection\eval_util.py", line 35, in <module>
#     from object_detection.metrics import coco_evaluation
#   File "C:\Users\noa_on_air\new_tensor\TFODCourse\tfod\lib\site-packages\object_detection-0.1-py3.8.egg\object_detection\metrics\coco_evaluation.py", line 25, in <module>
#     from object_detection.metrics import coco_tools
#   File "C:\Users\noa_on_air\new_tensor\TFODCourse\tfod\lib\site-packages\object_detection-0.1-py3.8.egg\object_detection\metrics\coco_tools.py", line 51, in <module>
#     from pycocotools import coco
#   File "C:\Users\noa_on_air\new_tensor\TFODCourse\tfod\lib\site-packages\pycocotools-2.0.2-py3.8-win-amd64.egg\pycocotools\coco.py", line 55, in <module>
#     from . import mask as maskUtils
#   File "C:\Users\noa_on_air\new_tensor\TFODCourse\tfod\lib\site-packages\pycocotools-2.0.2-py3.8-win-amd64.egg\pycocotools\mask.py", line 3, in <module>
#     import pycocotools._mask as _mask
#   File "pycocotools\_mask.pyx", line 1, in init pycocotools._mask
# ValueError: numpy.ndarray size changed, may indicate binary incompatibility. Expected 88 from C header, got 80 from PyObject

# %% [markdown]
# # 7. Evaluate the Model

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --checkpoint_dir={}".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'])

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\model_main_tf2.py --model_dir=Tensorflow\workspace\models\my_ssd_mobnet --pipeline_config_path=Tensorflow\workspace\models\my_ssd_mobnet\pipeline.config --checkpoint_dir=Tensorflow\workspace\models\my_ssd_mobnet

# %%
# !{command}

# %% [markdown]
# # 8. Load Train Model From Checkpoint

# %%
import os
import tensorflow as tf
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.builders import model_builder
from object_detection.utils import config_util

# %%
# Load pipeline config and build a detection model
configs = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])
detection_model = model_builder.build(model_config=configs['model'], is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
ckpt.restore(os.path.join(paths['CHECKPOINT_PATH'], 'ckpt-3')).expect_partial()

@tf.function
def detect_fn(image):
    image, shapes = detection_model.preprocess(image)
    prediction_dict = detection_model.predict(image, shapes)
    detections = detection_model.postprocess(prediction_dict, shapes)
    return detections

# %% [markdown]
# # 9. Detect from an Image

# %%
import cv2 
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
category_index = label_map_util.create_category_index_from_labelmap(files['LABELMAP'])

# %%
IMAGE_PATH = os.path.join(paths['IMAGE_PATH'], 'test', 'test.jpg')

# %%
img = cv2.imread(IMAGE_PATH)
image_np = np.array(img)

input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
detections = detect_fn(input_tensor)

num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
              for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

label_id_offset = 1
image_np_with_detections = image_np.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
            image_np_with_detections,
            detections['detection_boxes'],
            detections['detection_classes']+label_id_offset,
            detections['detection_scores'],
            category_index,
            use_normalized_coordinates=True,
            max_boxes_to_draw=5,
            min_score_thresh=.8,
            agnostic_mode=False)

plt.imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# # 10. Real Time Detections from your Webcam

# %%
# !pip uninstall opencv-python-headless -y

# %%
cap = cv2.VideoCapture(0)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

while cap.isOpened(): 
    ret, frame = cap.read()
    image_np = np.array(frame)
    
    input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
    detections = detect_fn(input_tensor)
    
    num_detections = int(detections.pop('num_detections'))
    detections = {key: value[0, :num_detections].numpy()
                  for key, value in detections.items()}
    detections['num_detections'] = num_detections

    # detection_classes should be ints.
    detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

    label_id_offset = 1
    image_np_with_detections = image_np.copy()

    viz_utils.visualize_boxes_and_labels_on_image_array(
                image_np_with_detections,
                detections['detection_boxes'],
                detections['detection_classes']+label_id_offset,
                detections['detection_scores'],
                category_index,
                use_normalized_coordinates=True,
                max_boxes_to_draw=5,
                min_score_thresh=.8,
                agnostic_mode=False)

    cv2.imshow('object detection',  cv2.resize(image_np_with_detections, (800, 600)))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        cap.release()
        cv2.destroyAllWindows()
        break

# %%
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# C:\Users\NOA_ON~1\AppData\Local\Temp/ipykernel_30912/1299754402.py in <module>
#      74 ref_image = cv2.imread("Ref_image.png")
#      75
# ---> 76 ref_image_face_width = face_data(ref_image)
#      77 focal_length_found = focal_length(
#      78     KNOWN_DISTANCE, KNOWN_WIDTH, ref_image_face_width)
#
# C:\Users\NOA_ON~1\AppData\Local\Temp/ipykernel_30912/1299754402.py in face_data(image)
#      62
#      63     face_width = 0
# ---> 64     gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#      65     faces = face_detector.detectMultiScale(gray_image, 1.3, 5)
#      66     for (x, y, h, w) in faces:
#
# error: OpenCV(4.5.3) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-q3d_8t8e\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %% [markdown]
# # 10. Freezing the Graph

# %%
FREEZE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'exporter_main_v2.py ')

# %%
command = "python {} --input_type=image_tensor --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(FREEZE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['OUTPUT_PATH'])

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\exporter_main_v2.py  --input_type=image_tensor --pipeline_config_path=Tensorflow\workspace\models\my_ssd_mobnet\pipeline.config --trained_checkpoint_dir=Tensorflow\workspace\models\my_ssd_mobnet --output_directory=Tensorflow\workspace\models\my_ssd_mobnet\export

# %%
# !{command}
# Out:
# 2021-10-13 01:26:06.048064: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-10-13 01:26:06.496087: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2032 MB memory:  -> device: 0, name: GeForce GTX 1650 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# WARNING:tensorflow:From C:\Users\noa_on_air\new_tensor\TFODCourse\tfod\lib\site-packages\tensorflow\python\autograph\impl\api.py:463: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W1013 01:26:07.091540 27676 deprecation.py:611] From C:\Users\noa_on_air\new_tensor\TFODCourse\tfod\lib\site-packages\tensorflow\python\autograph\impl\api.py:463: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x0000017909B3AEB0>, because it is not built.
# W1013 01:26:19.356070 27676 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x0000017909B3AEB0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x0000017909B71A30>, because it is not built.
# W1013 01:26:19.505669 27676 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x0000017909B71A30>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000179266EA5E0>, because it is not built.
# W1013 01:26:19.505669 27676 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000179266EA5E0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000001792AC3BF10>, because it is not built.
# W1013 01:26:19.505669 27676 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000001792AC3BF10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x000001792ACE7130>, because it is not built.
# W1013 01:26:19.505669 27676 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x000001792ACE7130>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001792ACE7C70>, because it is not built.
# W1013 01:26:19.505669 27676 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001792ACE7C70>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000001792ACE7730>, because it is not built.
# W1013 01:26:19.505669 27676 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000001792ACE7730>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x000001792ACE7B50>, because it is not built.
# W1013 01:26:19.505669 27676 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x000001792ACE7B50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001792AC39FD0>, because it is not built.
# W1013 01:26:19.505669 27676 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001792AC39FD0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000001792AC39A00>, because it is not built.
# W1013 01:26:19.505669 27676 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000001792AC39A00>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x000001792AC39E20>, because it is not built.
# W1013 01:26:19.505669 27676 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x000001792AC39E20>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001792AC39340>, because it is not built.
# W1013 01:26:19.505669 27676 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001792AC39340>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000001792AC39AF0>, because it is not built.
# W1013 01:26:19.505669 27676 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000001792AC39AF0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000017909EB62E0>, because it is not built.
# W1013 01:26:19.506633 27676 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000017909EB62E0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x0000017926696C40>, because it is not built.
# W1013 01:26:19.506633 27676 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x0000017926696C40>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001792AC2B1F0>, because it is not built.
# W1013 01:26:19.506633 27676 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001792AC2B1F0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000001792AC2BDF0>, because it is not built.
# W1013 01:26:19.506633 27676 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000001792AC2BDF0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001792AC2B880>, because it is not built.
# W1013 01:26:19.506633 27676 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001792AC2B880>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000001792AC2B250>, because it is not built.
# W1013 01:26:19.506633 27676 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000001792AC2B250>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001792AC2BD60>, because it is not built.
# W1013 01:26:19.506633 27676 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001792AC2BD60>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000001792AC2B940>, because it is not built.
# W1013 01:26:19.506633 27676 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000001792AC2B940>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000017909EB6310>, because it is not built.
# W1013 01:26:19.506633 27676 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000017909EB6310>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x00000179B3838AC0>, because it is not built.
# W1013 01:26:19.506633 27676 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x00000179B3838AC0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001792ADB2C10>, because it is not built.
# W1013 01:26:19.506633 27676 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001792ADB2C10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000001792ADB25E0>, because it is not built.
# W1013 01:26:19.506633 27676 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000001792ADB25E0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000179B17F7A90>, because it is not built.
# W1013 01:26:19.506633 27676 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000179B17F7A90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x00000179B17F7550>, because it is not built.
# W1013 01:26:19.506633 27676 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x00000179B17F7550>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000179B17F7BE0>, because it is not built.
# W1013 01:26:19.506633 27676 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000179B17F7BE0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x00000179B17F7280>, because it is not built.
# W1013 01:26:19.506633 27676 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x00000179B17F7280>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000017909EB6340>, because it is not built.
# W1013 01:26:19.507664 27676 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000017909EB6340>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x00000179B384BD00>, because it is not built.
# W1013 01:26:19.507664 27676 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x00000179B384BD00>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000179B382A580>, because it is not built.
# W1013 01:26:19.507664 27676 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000179B382A580>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x00000179B382A670>, because it is not built.
# W1013 01:26:19.507664 27676 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x00000179B382A670>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000179B382ACA0>, because it is not built.
# W1013 01:26:19.507664 27676 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000179B382ACA0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x00000179B382AD00>, because it is not built.
# W1013 01:26:19.507664 27676 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x00000179B382AD00>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000179B382A730>, because it is not built.
# W1013 01:26:19.507664 27676 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000179B382A730>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x00000179B382AE20>, because it is not built.
# W1013 01:26:19.507664 27676 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x00000179B382AE20>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001792AD36250>, because it is not built.
# W1013 01:26:19.507664 27676 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001792AD36250>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000001792669C340>, because it is not built.
# W1013 01:26:19.507664 27676 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000001792669C340>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001792670D9A0>, because it is not built.
# W1013 01:26:19.507664 27676 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001792670D9A0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000001792670DFA0>, because it is not built.
# W1013 01:26:19.507664 27676 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000001792670DFA0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001792670D5B0>, because it is not built.
# W1013 01:26:19.507664 27676 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001792670D5B0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000001792670DD60>, because it is not built.
# W1013 01:26:19.507664 27676 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000001792670DD60>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001792AC68F10>, because it is not built.
# W1013 01:26:19.507664 27676 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001792AC68F10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000001792AC68490>, because it is not built.
# W1013 01:26:19.507664 27676 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000001792AC68490>, because it is not built.
# 2021-10-13 01:26:27.749801: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# W1013 01:26:42.492937 27676 save.py:249] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_fn while saving (showing 5 of 260). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Tensorflow\workspace\models\my_ssd_mobnet\export\saved_model\assets
# I1013 01:26:46.516074 27676 builder_impl.py:780] Assets written to: Tensorflow\workspace\models\my_ssd_mobnet\export\saved_model\assets
# INFO:tensorflow:Writing pipeline config file to Tensorflow\workspace\models\my_ssd_mobnet\export\pipeline.config
# I1013 01:26:47.281096 27676 config_util.py:253] Writing pipeline config file to Tensorflow\workspace\models\my_ssd_mobnet\export\pipeline.config

# %% [markdown]
# # 11. Conversion to TFJS

# %%
# !pip install tensorflowjs
# Out:
# Collecting tensorflowjs
#   Downloading tensorflowjs-3.9.0-py3-none-any.whl (64 kB)
# Collecting tensorflow-hub<0.13,>=0.7.0
#   Downloading tensorflow_hub-0.12.0-py2.py3-none-any.whl (108 kB)
# Requirement already satisfied: six<2,>=1.12.0 in c:\users\noa_on_air\new_tensor\tfodcourse\tfod\lib\site-packages (from tensorflowjs) (1.15.0)
# Requirement already satisfied: tensorflow<3,>=2.1.0 in c:\users\noa_on_air\new_tensor\tfodcourse\tfod\lib\site-packages (from tensorflowjs) (2.6.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\noa_on_air\new_tensor\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.18.1)
# Requirement already satisfied: grpcio<2.0,>=1.37.0 in c:\users\noa_on_air\new_tensor\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.41.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\users\noa_on_air\new_tensor\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.1.2)
# Requirement already satisfied: gast==0.4.0 in c:\users\noa_on_air\new_tensor\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.4.0)
# Requirement already satisfied: wheel~=0.35 in c:\users\noa_on_air\new_tensor\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.37.0)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\noa_on_air\new_tensor\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.12.1)
# Requirement already satisfied: h5py~=3.1.0 in c:\users\noa_on_air\new_tensor\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.1.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\users\noa_on_air\new_tensor\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.3.0)
# Requirement already satisfied: tensorflow-estimator~=2.6 in c:\users\noa_on_air\new_tensor\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.6.0)
# Requirement already satisfied: keras~=2.6 in c:\users\noa_on_air\new_tensor\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.6.0)
# Requirement already satisfied: tensorboard~=2.6 in c:\users\noa_on_air\new_tensor\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.6.0)
# Requirement already satisfied: numpy~=1.19.2 in c:\users\noa_on_air\new_tensor\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.19.5)
# Requirement already satisfied: astunparse~=1.6.3 in c:\users\noa_on_air\new_tensor\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.6.3)
# Requirement already satisfied: clang~=5.0 in c:\users\noa_on_air\new_tensor\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (5.0)
# Requirement already satisfied: google-pasta~=0.2 in c:\users\noa_on_air\new_tensor\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.2.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in c:\users\noa_on_air\new_tensor\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.12)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\noa_on_air\new_tensor\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.7.4.3)
# Requirement already satisfied: termcolor~=1.1.0 in c:\users\noa_on_air\new_tensor\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.1.0)
# Requirement already satisfied: absl-py~=0.10 in c:\users\noa_on_air\new_tensor\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.14.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\noa_on_air\new_tensor\tfodcourse\tfod\lib\site-packages (from tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (3.3.4)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\noa_on_air\new_tensor\tfodcourse\tfod\lib\site-packages (from tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (1.35.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\noa_on_air\new_tensor\tfodcourse\tfod\lib\site-packages (from tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (2.26.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\noa_on_air\new_tensor\tfodcourse\tfod\lib\site-packages (from tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (2.0.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\noa_on_air\new_tensor\tfodcourse\tfod\lib\site-packages (from tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (0.4.6)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\noa_on_air\new_tensor\tfodcourse\tfod\lib\site-packages (from tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (49.2.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\noa_on_air\new_tensor\tfodcourse\tfod\lib\site-packages (from tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\noa_on_air\new_tensor\tfodcourse\tfod\lib\site-packages (from tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (1.8.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\noa_on_air\new_tensor\tfodcourse\tfod\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\noa_on_air\new_tensor\tfodcourse\tfod\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\noa_on_air\new_tensor\tfodcourse\tfod\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\noa_on_air\new_tensor\tfodcourse\tfod\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (1.3.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\noa_on_air\new_tensor\tfodcourse\tfod\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\noa_on_air\new_tensor\tfodcourse\tfod\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\noa_on_air\new_tensor\tfodcourse\tfod\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\noa_on_air\new_tensor\tfodcourse\tfod\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (2.0.7)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\noa_on_air\new_tensor\tfodcourse\tfod\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\noa_on_air\new_tensor\tfodcourse\tfod\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow<3,>=2.1.0->tensorflowjs) (3.1.1)
# Installing collected packages: tensorflow-hub, tensorflowjs
# Successfully installed tensorflow-hub-0.12.0 tensorflowjs-3.9.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-models-official 2.6.0 requires google-api-python-client>=1.6.7, which is not installed.
# tf-models-official 2.6.0 requires kaggle>=1.3.9, which is not installed.
# tf-models-official 2.6.0 requires oauth2client, which is not installed.
# tf-models-official 2.6.0 requires opencv-python-headless, which is not installed.
# tf-models-official 2.6.0 requires psutil>=5.4.3, which is not installed.
# tf-models-official 2.6.0 requires py-cpuinfo>=3.3.0, which is not installed.
# tf-models-official 2.6.0 requires sacrebleu, which is not installed.
# tf-models-official 2.6.0 requires sentencepiece, which is not installed.
# tf-models-official 2.6.0 requires seqeval, which is not installed.
# tf-models-official 2.6.0 requires tensorflow-datasets, which is not installed.
# tf-models-official 2.6.0 requires tensorflow-model-optimization>=0.4.1, which is not installed.
# tf-models-official 2.6.0 requires tensorflow-text>=2.5.0, which is not installed.

# %%
command = "tensorflowjs_converter --input_format=tf_saved_model --output_node_names='detection_boxes,detection_classes,detection_features,detection_multiclass_scores,detection_scores,num_detections,raw_detection_boxes,raw_detection_scores' --output_format=tfjs_graph_model --signature_name=serving_default {} {}".format(os.path.join(paths['OUTPUT_PATH'], 'saved_model'), paths['TFJS_PATH'])

# %%
print(command)
# Out:
# tensorflowjs_converter --input_format=tf_saved_model --output_node_names='detection_boxes,detection_classes,detection_features,detection_multiclass_scores,detection_scores,num_detections,raw_detection_boxes,raw_detection_scores' --output_format=tfjs_graph_model --signature_name=serving_default Tensorflow\workspace\models\my_ssd_mobnet\export\saved_model Tensorflow\workspace\models\my_ssd_mobnet\tfjsexport

# %%
# !{command}
# Out:
# Writing weight file Tensorflow\workspace\models\my_ssd_mobnet\tfjsexport\model.json...
# 2021-10-13 01:26:53.190702: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-10-13 01:26:53.759547: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2149 MB memory:  -> device: 0, name: GeForce GTX 1650 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# 2021-10-13 01:27:03.226613: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# 2021-10-13 01:27:03.226724: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2021-10-13 01:27:03.228260: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2149 MB memory:  -> device: 0, name: GeForce GTX 1650 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# 2021-10-13 01:27:03.487817: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: Graph size after: 3654 nodes (3244), 4879 edges (4462), time = 156.912ms.
#   function_optimizer: function_optimizer did nothing. time = 2.847ms.
#
# 2021-10-13 01:27:06.872208: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   debug_stripper: Graph size after: 3381 nodes (0), 4687 edges (0), time = 9.675ms.
#   model_pruner: Graph size after: 2933 nodes (-448), 4239 edges (-448), time = 56.546ms.
#   constant_folding: Graph size after: 1405 nodes (-1528), 2471 edges (-1768), time = 163.646ms.
#   arithmetic_optimizer: Graph size after: 1421 nodes (16), 2481 edges (10), time = 28.771ms.
#   dependency_optimizer: Graph size after: 1326 nodes (-95), 1481 edges (-1000), time = 20.801ms.
#   model_pruner: Graph size after: 1326 nodes (0), 1481 edges (0), time = 11.201ms.
#   constant_folding: Graph size after: 1326 nodes (0), 1481 edges (0), time = 28.977ms.
#   arithmetic_optimizer: Graph size after: 1326 nodes (0), 1481 edges (0), time = 27.074ms.
#   dependency_optimizer: Graph size after: 1326 nodes (0), 1481 edges (0), time = 15.61ms.
#   debug_stripper: debug_stripper did nothing. time = 1.503ms.
#   model_pruner: Graph size after: 1326 nodes (0), 1481 edges (0), time = 7.528ms.
#   constant_folding: Graph size after: 1326 nodes (0), 1481 edges (0), time = 42.104ms.
#   arithmetic_optimizer: Graph size after: 1326 nodes (0), 1481 edges (0), time = 29.967ms.
#   dependency_optimizer: Graph size after: 1326 nodes (0), 1481 edges (0), time = 19.683ms.
#   model_pruner: Graph size after: 1326 nodes (0), 1481 edges (0), time = 10.08ms.
#   constant_folding: Graph size after: 1326 nodes (0), 1481 edges (0), time = 35.434ms.
#   arithmetic_optimizer: Graph size after: 1326 nodes (0), 1481 edges (0), time = 30.316ms.
#   dependency_optimizer: Graph size after: 1326 nodes (0), 1481 edges (0), time = 21.689ms.
#
# 2021-10-13 01:27:14.852738: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1137] Optimization results for grappler item: graph_to_optimize
#   remapper: Graph size after: 1290 nodes (-112), 1141 edges (-112), time = 7.957ms.
#   constant_folding: Graph size after: 986 nodes (-304), 1141 edges (0), time = 82.065ms.
#   arithmetic_optimizer: Graph size after: 986 nodes (0), 1141 edges (0), time = 28.939ms.
#   dependency_optimizer: Graph size after: 986 nodes (0), 1141 edges (0), time = 16.572ms.
#   remapper: Graph size after: 986 nodes (0), 1141 edges (0), time = 9.007ms.
#   constant_folding: Graph size after: 986 nodes (0), 1141 edges (0), time = 33.885ms.
#   arithmetic_optimizer: Graph size after: 986 nodes (0), 1141 edges (0), time = 21.187ms.
#   dependency_optimizer: Graph size after: 986 nodes (0), 1141 edges (0), time = 13.414ms.

# %%
# Test Code: https://github.com/nicknochnack/RealTimeSignLanguageDetectionwithTFJS

# %% [markdown]
# # 12. Conversion to TFLite

# %%
TFLITE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'export_tflite_graph_tf2.py ')

# %%
command = "python {} --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(TFLITE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['TFLITE_PATH'])

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\export_tflite_graph_tf2.py  --pipeline_config_path=Tensorflow\workspace\models\my_ssd_mobnet\pipeline.config --trained_checkpoint_dir=Tensorflow\workspace\models\my_ssd_mobnet --output_directory=Tensorflow\workspace\models\my_ssd_mobnet\tfliteexport

# %%
# !{command}
# Out:
# 2021-10-13 01:27:21.431643: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-10-13 01:27:22.014782: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2149 MB memory:  -> device: 0, name: GeForce GTX 1650 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# 2021-10-13 01:27:28.809750: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2149 MB memory:  -> device: 0, name: GeForce GTX 1650 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# 2021-10-13 01:27:30.430464: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2149 MB memory:  -> device: 0, name: GeForce GTX 1650 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x000002088B922310>, because it is not built.
# W1013 01:27:31.032738  9632 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x000002088B922310>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x000002088BC5F250>, because it is not built.
# W1013 01:27:31.326921  9632 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x000002088BC5F250>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000208ADE5B040>, because it is not built.
# W1013 01:27:31.327916  9632 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000208ADE5B040>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x00000208ADE5B0A0>, because it is not built.
# W1013 01:27:31.327916  9632 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x00000208ADE5B0A0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x00000208ADE5B850>, because it is not built.
# W1013 01:27:31.327916  9632 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x00000208ADE5B850>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000208ADE5B670>, because it is not built.
# W1013 01:27:31.327916  9632 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000208ADE5B670>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x00000208ADE5B160>, because it is not built.
# W1013 01:27:31.327916  9632 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x00000208ADE5B160>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x000002093C007100>, because it is not built.
# W1013 01:27:31.327916  9632 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x000002093C007100>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002093C0077C0>, because it is not built.
# W1013 01:27:31.327916  9632 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002093C0077C0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000002093C007970>, because it is not built.
# W1013 01:27:31.327916  9632 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000002093C007970>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x000002093C007C10>, because it is not built.
# W1013 01:27:31.327916  9632 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.convolutional.SeparableConv2D object at 0x000002093C007C10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002093C007AC0>, because it is not built.
# W1013 01:27:31.327916  9632 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002093C007AC0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000002093C007CD0>, because it is not built.
# W1013 01:27:31.327916  9632 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000002093C007CD0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002088BC5F820>, because it is not built.
# W1013 01:27:31.327916  9632 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002088BC5F820>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x00000208ADE51A60>, because it is not built.
# W1013 01:27:31.327916  9632 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x00000208ADE51A60>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000208ADE5E400>, because it is not built.
# W1013 01:27:31.327916  9632 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000208ADE5E400>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x00000208ADE5ED30>, because it is not built.
# W1013 01:27:31.327916  9632 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x00000208ADE5ED30>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002093C033220>, because it is not built.
# W1013 01:27:31.327916  9632 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002093C033220>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000002093C033130>, because it is not built.
# W1013 01:27:31.328913  9632 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000002093C033130>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002093C033C10>, because it is not built.
# W1013 01:27:31.328913  9632 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002093C033C10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000002093C033970>, because it is not built.
# W1013 01:27:31.328913  9632 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000002093C033970>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002088BC5F850>, because it is not built.
# W1013 01:27:31.328913  9632 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002088BC5F850>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000002093C022BB0>, because it is not built.
# W1013 01:27:31.328913  9632 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000002093C022BB0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002093C036400>, because it is not built.
# W1013 01:27:31.328913  9632 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002093C036400>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000002093C036730>, because it is not built.
# W1013 01:27:31.328913  9632 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000002093C036730>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002093C036A60>, because it is not built.
# W1013 01:27:31.328913  9632 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002093C036A60>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000002093C0367F0>, because it is not built.
# W1013 01:27:31.328913  9632 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000002093C0367F0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002093C036FA0>, because it is not built.
# W1013 01:27:31.328913  9632 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002093C036FA0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000002093C036B80>, because it is not built.
# W1013 01:27:31.328913  9632 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000002093C036B80>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002088BC5F880>, because it is not built.
# W1013 01:27:31.328913  9632 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002088BC5F880>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000002093C000A00>, because it is not built.
# W1013 01:27:31.328913  9632 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000002093C000A00>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000208ADE28B20>, because it is not built.
# W1013 01:27:31.328913  9632 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000208ADE28B20>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x00000208ADE28CA0>, because it is not built.
# W1013 01:27:31.328913  9632 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x00000208ADE28CA0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000208ADE281C0>, because it is not built.
# W1013 01:27:31.328913  9632 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000208ADE281C0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x00000208ADE28280>, because it is not built.
# W1013 01:27:31.328913  9632 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x00000208ADE28280>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002093C0154C0>, because it is not built.
# W1013 01:27:31.328913  9632 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002093C0154C0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000002093C015610>, because it is not built.
# W1013 01:27:31.328913  9632 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000002093C015610>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002093C0151C0>, because it is not built.
# W1013 01:27:31.329909  9632 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002093C0151C0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x00000208ADDB8730>, because it is not built.
# W1013 01:27:31.329909  9632 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x00000208ADDB8730>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002093C028640>, because it is not built.
# W1013 01:27:31.329909  9632 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002093C028640>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000002093C0282E0>, because it is not built.
# W1013 01:27:31.329909  9632 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000002093C0282E0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002093C028790>, because it is not built.
# W1013 01:27:31.329909  9632 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002093C028790>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000002093C028B50>, because it is not built.
# W1013 01:27:31.329909  9632 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000002093C028B50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002093C028D30>, because it is not built.
# W1013 01:27:31.329909  9632 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002093C028D30>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000002093C028F70>, because it is not built.
# W1013 01:27:31.329909  9632 save_impl.py:71] Skipping full serialization of Keras layer <keras.layers.core.Lambda object at 0x000002093C028F70>, because it is not built.
# 2021-10-13 01:27:39.582063: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# 2021-10-13 01:27:40.811742: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2149 MB memory:  -> device: 0, name: GeForce GTX 1650 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# W1013 01:27:52.247166  9632 save.py:249] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxPredictor_layer_call_fn while saving (showing 5 of 260). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Tensorflow\workspace\models\my_ssd_mobnet\tfliteexport\saved_model\assets
# I1013 01:27:56.292531  9632 builder_impl.py:780] Assets written to: Tensorflow\workspace\models\my_ssd_mobnet\tfliteexport\saved_model\assets

# %%
FROZEN_TFLITE_PATH = os.path.join(paths['TFLITE_PATH'], 'saved_model')
TFLITE_MODEL = os.path.join(paths['TFLITE_PATH'], 'saved_model', 'detect.tflite')

# %%
command = "tflite_convert \
--saved_model_dir={} \
--output_file={} \
--input_shapes=1,300,300,3 \
--input_arrays=normalized_input_image_tensor \
--output_arrays='TFLite_Detection_PostProcess','TFLite_Detection_PostProcess:1','TFLite_Detection_PostProcess:2','TFLite_Detection_PostProcess:3' \
--inference_type=FLOAT \
--allow_custom_ops".format(FROZEN_TFLITE_PATH, TFLITE_MODEL, )

# %%
print(command)
# Out:
# tflite_convert --saved_model_dir=Tensorflow\workspace\models\my_ssd_mobnet\tfliteexport\saved_model --output_file=Tensorflow\workspace\models\my_ssd_mobnet\tfliteexport\saved_model\detect.tflite --input_shapes=1,300,300,3 --input_arrays=normalized_input_image_tensor --output_arrays='TFLite_Detection_PostProcess','TFLite_Detection_PostProcess:1','TFLite_Detection_PostProcess:2','TFLite_Detection_PostProcess:3' --inference_type=FLOAT --allow_custom_ops

# %%
# !{command}
# Out:
# 2021-10-12 22:38:00.540353: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-10-12 22:38:01.074877: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2149 MB memory:  -> device: 0, name: GeForce GTX 1650 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# 2021-10-12 22:38:10.665269: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:351] Ignored output_format.
# 2021-10-12 22:38:10.665286: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:354] Ignored drop_control_dependency.
# 2021-10-12 22:38:10.665290: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:360] Ignored change_concat_input_ranges.
# 2021-10-12 22:38:10.667485: I tensorflow/cc/saved_model/reader.cc:38] Reading SavedModel from: Tensorflow\workspace\models\my_ssd_mobnet\tfliteexport\saved_model
# 2021-10-12 22:38:10.745980: I tensorflow/cc/saved_model/reader.cc:90] Reading meta graph with tags { serve }
# 2021-10-12 22:38:10.746008: I tensorflow/cc/saved_model/reader.cc:132] Reading SavedModel debug info (if present) from: Tensorflow\workspace\models\my_ssd_mobnet\tfliteexport\saved_model
# 2021-10-12 22:38:11.106710: I tensorflow/cc/saved_model/loader.cc:211] Restoring SavedModel bundle.
# 2021-10-12 22:38:11.786105: I tensorflow/cc/saved_model/loader.cc:195] Running initialization op on SavedModel bundle at path: Tensorflow\workspace\models\my_ssd_mobnet\tfliteexport\saved_model
# 2021-10-12 22:38:12.049729: I tensorflow/cc/saved_model/loader.cc:283] SavedModel load for tags { serve }; Status: success: OK. Took 1382227 microseconds.
# 2021-10-12 22:38:12.916018: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:210] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2021-10-12 22:38:13.576006: I tensorflow/compiler/mlir/lite/flatbuffer_export.cc:1899] Estimated count of arithmetic ops: 1.698 G  ops, equivalently 0.849 G  MACs

# %% [markdown]
# # 13. Zip and Export Models

# %%
# !tar -czf models.tar.gz {paths['CHECKPOINT_PATH']}

# %%
from google.colab import drive
drive.mount('/content/drive')
